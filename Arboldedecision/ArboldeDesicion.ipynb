# %%
# Load necesary Library.

# Manipulación y visualización de datos
import pandas as pd

# Generar los graficos
import matplotlib.pyplot as plt

# Generar graficos con mejor aspecto
import seaborn as sns

# Libreria de matematicas
import numpy as np

# libreria para obtener mejores valores
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score

# %%
DataArbolDecision = pd.read_csv("C:/Users/ander/Downloads/DatosUNAD/Arboldedecision/wine.data", sep=",")

# %%
DataArbolDecision
# Out:
#     Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 1     14.23        1.71  2.43               15.6        127           2.80
# 1     13.20        1.78  2.14               11.2        100           2.65
# 1     13.16        2.36  2.67               18.6        101           2.80
# 1     14.37        1.95  2.50               16.8        113           3.85
# 1     13.24        2.59  2.87               21.0        118           2.80
# ..      ...         ...   ...                ...        ...            ...
# 3     13.71        5.65  2.45               20.5         95           1.68
# 3     13.40        3.91  2.48               23.0        102           1.80
# 3     13.27        4.28  2.26               20.0        120           1.59
# 3     13.17        2.59  2.37               20.0        120           1.65
# 3     14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
DataArbolDecision.describe()
# Out:
#           Alcohol  Malic acid         Ash  Alcalinity of ash   Magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
plt.hist(DataArbolDecision.Hue)
# Out:
# (array([17., 16., 20., 37., 38., 24., 20.,  5.,  0.,  1.]),
#  array([0.48 , 0.603, 0.726, 0.849, 0.972, 1.095, 1.218, 1.341, 1.464,
#         1.587, 1.71 ]),
#  <BarContainer object of 10 artists>)

# %%
# Voy a predecir con el Hue-Tonalidad, Magnesium-Magnesio, Ash-Cenizas,Color intensity-Intensidad del color el nivel de Alcohol
predictors_col = ['Hue','Magnesium','Ash','Color intensity']
target_col = ['Alcohol'] #Variable o columna objetivo

# %%
# Asigno los valores obtenidos en nuevas variables
predictors = DataArbolDecision[predictors_col]
target = DataArbolDecision[target_col]

# %%
# Realizzo el entrenamiento "train" y su correspondiente prueba, en este caso dejare 20% para el test
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size = 0.25, random_state = 13)

# %%
# Creo el arbol de decisión
tree = DecisionTreeClassifier()

# %%
# Ahora entreno el arbol de decision con los valores de entrenamiento X_train y y_train
arbol = tree.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Ahora entreno el arbol de decision con los valores de entrenamiento X_train y y_train
# ----> 2 arbol = tree.fit(X_train, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# ...

# %%
# Graficamos el arbol resultante
pt_tree(arbool)

# Evaluo la predicción
predicciones = arbol.predict(X_test)
